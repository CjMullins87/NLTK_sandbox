# %%
import numpy as np
import matplotlib.pyplot as plt

import nltk

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1AF1-3980
#
#  Directory of C:\Users\mulli\Data-Science-Local-Copy\Resume Optimization
#
# 05/16/2020  08:38 PM    <DIR>          .
# 05/16/2020  08:38 PM    <DIR>          ..
# 05/14/2020  05:29 PM    <DIR>          .ipynb_checkpoints
# 05/14/2020  05:32 PM            59,762 job_descriptions.txt
# 05/16/2020  08:38 PM           212,393 Untitled.ipynb
#                2 File(s)        272,155 bytes
#                3 Dir(s)  55,338,561,536 bytes free

# %%
f = open('job_descriptions.txt', 'rU')
raw = f.read()
# Out:
# C:\Users\mulli\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %%
raw
# Out:
# 'ï»¿We are seeking a data scientist who is passionate about business process analysis and the intellectual challenge that it offers. The person we seek has previous experience in successful management consulting performing strategic analysis and, or, operations improvement projects for one or more of the larger, well known consultancies. The data scientist will support our field consultant staff by performing analysis on client data and assisting with the development, implementation and integration of pioneering solutions using different methods, techniques and tools. You will ensure the rigor and underlying logic of the team\'s findings, optimize the analytical storyline and develop superior, easy to comprehend documentation and Power BI dashboards. \n \nThe data scientist will be responsible for gathering, analyzing and documenting business processes, developing business cases, developing BI dashboards and providing domain knowledge to the team. This position will occasionally requ
# ...

# %%
len(raw)
# Out:
# 59230

# %%
test = FreqDist(raw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-093717c90686> in <module>
# ----> 1 test = FreqDist(raw)
#
# NameError: name 'FreqDist' is not defined

# %%
nltk.FreqDist(raw)
# Out:
# FreqDist({' ': 11243, 'e': 4998, 'a': 3942, 'i': 3855, 't': 3830, 'n': 3704, 'o': 3171, 's': 3166, 'r': 2689, 'd': 1946, ...})

# %%
print(raw.strip())
# Out:
# ï»¿We are seeking a data scientist who is passionate about business process analysis and the intellectual challenge that it offers. The person we seek has previous experience in successful management consulting performing strategic analysis and, or, operations improvement projects for one or more of the larger, well known consultancies. The data scientist will support our field consultant staff by performing analysis on client data and assisting with the development, implementation and integration of pioneering solutions using different methods, techniques and tools. You will ensure the rigor and underlying logic of the team's findings, optimize the analytical storyline and develop superior, easy to comprehend documentation and Power BI dashboards.
#
# ...

# %%
print(raw.split())
# Out:
# ['ï»¿We', 'are', 'seeking', 'a', 'data', 'scientist', 'who', 'is', 'passionate', 'about', 'business', 'process', 'analysis', 'and', 'the', 'intellectual', 'challenge', 'that', 'it', 'offers.', 'The', 'person', 'we', 'seek', 'has', 'previous', 'experience', 'in', 'successful', 'management', 'consulting', 'performing', 'strategic', 'analysis', 'and,', 'or,', 'operations', 'improvement', 'projects', 'for', 'one', 'or', 'more', 'of', 'the', 'larger,', 'well', 'known', 'consultancies.', 'The', 'data', 'scientist', 'will', 'support', 'our', 'field', 'consultant', 'staff', 'by', 'performing', 'analysis', 'on', 'client', 'data', 'and', 'assisting', 'with', 'the', 'development,', 'implementation', 'and', 'integration', 'of', 'pioneering', 'solutions', 'using', 'different', 'methods,', 'techniques', 'and', 'tools.', 'You', 'will', 'ensure', 'the', 'rigor', 'and', 'underlying', 'logic', 'of', 'the', "team's", 'findings,', 'optimize', 'the', 'analytical', 'storyline', 'and', 'develop', 'superior
# ...

# %%
nltk.FreqDist(raw.split())
# Out:
# FreqDist({'and': 535, '*': 272, 'to': 236, 'data': 170, 'of': 166, 'the': 149, 'with': 146, 'in': 114, 'a': 104, 'for': 90, ...})

# %%
test = raw.split()

# %%
test
# Out:
# ['ï»¿We',
#  'are',
#  'seeking',
#  'a',
#  'data',
#  'scientist',
#  'who',
#  'is',
#  'passionate',
#  'about',
#  'business',
#  'process',
#  'analysis',
#  'and',
#  'the',
#  'intellectual',
#  'challenge',
#  'that',
#  'it',
#  'offers.',
#  'The',
#  'person',
#  'we',
#  'seek',
#  'has',
#  'previous',
#  'experience',
#  'in',
#  'successful',
#  'management',
#  'consulting',
#  'performing',
#  'strategic',
#  'analysis',
#  'and,',
#  'or,',
#  'operations',
#  'improvement',
#  'projects',
#  'for',
#  'one',
#  'or',
#  'more',
#  'of',
#  'the',
#  'larger,',
#  'well',
#  'known',
#  'consultancies.',
#  'The',
#  'data',
#  'scientist',
#  'will',
#  'support',
#  'our',
#  'field',
#  'consultant',
#  'staff',
#  'by',
#  'performing',
#  'analysis',
#  'on',
#  'client',
#  'data',
#  'and',
#  'assisting',
#  'with',
#  'the',
#  'development,',
#  'implementation',
#  'and',
#  'integration',
#  'of',
#  'pioneering',
#  'solutions',
#  'using',
# ...

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mulli\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords.words()
# Out:
# ['إذ',
#  'إذا',
#  'إذما',
#  'إذن',
#  'أف',
#  'أقل',
#  'أكثر',
#  'ألا',
#  'إلا',
#  'التي',
#  'الذي',
#  'الذين',
#  'اللاتي',
#  'اللائي',
#  'اللتان',
#  'اللتيا',
#  'اللتين',
#  'اللذان',
#  'اللذين',
#  'اللواتي',
#  'إلى',
#  'إليك',
#  'إليكم',
#  'إليكما',
#  'إليكن',
#  'أم',
#  'أما',
#  'أما',
#  'إما',
#  'أن',
#  'إن',
#  'إنا',
#  'أنا',
#  'أنت',
#  'أنتم',
#  'أنتما',
#  'أنتن',
#  'إنما',
#  'إنه',
#  'أنى',
#  'أنى',
#  'آه',
#  'آها',
#  'أو',
#  'أولاء',
#  'أولئك',
#  'أوه',
#  'آي',
#  'أي',
#  'أيها',
#  'إي',
#  'أين',
#  'أين',
#  'أينما',
#  'إيه',
#  'بخ',
#  'بس',
#  'بعد',
#  'بعض',
#  'بك',
#  'بكم',
#  'بكم',
#  'بكما',
#  'بكن',
#  'بل',
#  'بلى',
#  'بما',
#  'بماذا',
#  'بمن',
#  'بنا',
#  'به',
#  'بها',
#  'بهم',
#  'بهما',
#  'بهن',
#  'بي',
#  'بين',
#  'بيد',
#  'تلك',
#  'تلكم',
#  'تلكما',
#  'ته',
#  'تي',
#  'تين',
#  'تينك',
#  'ثم',
#  'ثمة',
#  'حاشا',
#  'حبذا',
#  'حتى',
#  'حيث',
#  'حيثما',
#  'حين',
#  'خلا',
#  'دون',
# ...

# %%
clean = [word for word in test if not word in stopwords.words()]

# %%
clean
# Out:
# ['ï»¿We',
#  'seeking',
#  'data',
#  'scientist',
#  'passionate',
#  'business',
#  'process',
#  'analysis',
#  'intellectual',
#  'challenge',
#  'offers.',
#  'The',
#  'person',
#  'seek',
#  'previous',
#  'experience',
#  'successful',
#  'management',
#  'consulting',
#  'performing',
#  'strategic',
#  'analysis',
#  'and,',
#  'or,',
#  'operations',
#  'improvement',
#  'projects',
#  'larger,',
#  'well',
#  'known',
#  'consultancies.',
#  'The',
#  'data',
#  'scientist',
#  'support',
#  'field',
#  'consultant',
#  'staff',
#  'performing',
#  'analysis',
#  'client',
#  'data',
#  'assisting',
#  'development,',
#  'implementation',
#  'integration',
#  'pioneering',
#  'solutions',
#  'using',
#  'different',
#  'methods,',
#  'techniques',
#  'tools.',
#  'You',
#  'ensure',
#  'rigor',
#  'underlying',
#  'logic',
#  "team's",
#  'findings,',
#  'optimize',
#  'analytical',
#  'storyline',
#  'develop',
#  'superior,',
#  'easy',
#  'comprehend',
# ...

# %%
hist = nltk.FreqDist(clean)

# %%
plt.figure(figsize = [10,10])
hist.plot(30)

# %%
a = 0
for i in clean:
    if i == "*":
        a += 1

print(a)
# Out:
# 272

# %%
plt.style.use('ggplot')
clean = [word for word in clean if not word == "*"]
hist = nltk.FreqDist(clean)
hist.plot(30)

# %%
plt.style.use('ggplot')
plt.figure(figsize = (10,10))
clean = [word for word in clean if not word == "________________"]
hist = nltk.FreqDist(clean)
hist.plot(30)
